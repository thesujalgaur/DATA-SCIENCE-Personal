# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv('iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
iris['Species']=iris['Species'].replace({'Iris-setosa':0,
                         'Iris-versicolor':1,
                         'Iris-virginica':2})
iris.sample(5)
# Out:
# /var/folders/x6/3z1b_1m13nn8gl_5jykvtxy40000gn/T/ipykernel_7847/647244328.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species']=iris['Species'].replace({'Iris-setosa':0,
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 76    77            6.8           2.8            4.8           1.4        1
# 41    42            4.5           2.3            1.3           0.3        0
# 118  119            7.7           2.6            6.9           2.3        2
# 123  124            6.3           2.7            4.9           1.8        2
# 38    39            4.4           3.0            1.3           0.2        0

# %%
plt.figure(figsize=(15,7))
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='twilight',alpha=0.9)
plt.xlabel('sepal Length')
plt.ylabel('Petal Length')
plt.colorbar()
#alpha is opacity ( Density)

# %% [markdown]
# # Annotations
# *isko use karke hum apne graph pe ek text ko place kar skte h*

# %%
batter=pd.read_csv('batter.csv')
batter
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
sample_df=batter.head(100).sample(25,random_state=5)

# %%
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# 69     D Padikkal  1260  28.000000   119.205298
# 94     SO Hetmyer   831  30.777778   144.020797
# 56        PP Shaw  1588  25.206349   143.580470
# 22       PA Patel  2848  22.603175   116.625717
# 39     GJ Maxwell  2320  25.494505   147.676639
# 24        SS Iyer  2780  31.235955   121.132898

# %%
plt.figure(figsize=(18,5))
plt.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs'])
for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])

# %%
x=[1,2,3,4]
y=[5,6,7,8]
plt.scatter(x,y)
plt.text(1,5,'Point 1')
plt.text(2,6,'Point 2')
plt.text(3,7,'Point 3')
plt.text(4,8,'Point 4',fontdict={'size':14,'color':'Red'})
# Out:
# Text(4, 8, 'Point 4')

# %%
#horizontal and vertical line
plt.figure(figsize=(18,5))
plt.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs'])
for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])
plt.axhline(130,color='red')
plt.axhline(140,color='black')
plt.axvline(30,color='red')

# %%
batter
plt.scatter(batter['avg'],batter['strike_rate'])
plt.title('something')
# Out:
# Text(0.5, 1.0, 'something')

# %%
fig,ax=plt.subplots(figsize=(15,6))
ax.scatter(batter['avg'],batter['strike_rate'],color='red')
ax.set_title('Something')
# Out:
# Text(0.5, 1.0, 'Something')

# %%
fig,ax=plt.subplots(figsize=(15,8))
ax.plot(batter['avg'],batter['strike_rate'])
ax.set_title('Something')
ax.set_ylabel('strike rate')
ax.set_xlabel('run')
# Out:
# Text(0.5, 0, 'run')

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,10))
ax[0,0].scatter(batter['avg'],batter['strike_rate'],color='brown',marker='D')
ax[0,1].scatter(batter['avg'],batter['runs'],color='pink')
ax[1,0].hist(batter['avg'],color='pink')
ax[1,1].hist(batter['runs'],color='pink')
ax[0].set_title('avg vs strike rate')
ax[1].set_title('avg vs runs')
ax[0].set_xlabel('Strike rate')
ax[0].set_ylabel('avg run')
ax[1].set_xlabel('avg')
ax[1].set_ylabel('runs')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 6
#       4 ax[1,0].hist(batter['avg'],color='pink')
#       5 ax[1,1].hist(batter['runs'],color='pink')
# ----> 6 ax[0].set_title('avg vs strike rate')
#       7 ax[1].set_title('avg vs runs')
#       8 ax[0].set_xlabel('Strike rate')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'set_title'
