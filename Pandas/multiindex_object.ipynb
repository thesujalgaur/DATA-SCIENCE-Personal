# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Series is 1D and Dataframe  is 2D object
# 1. # But Why
# 2. # and what exactly index is ??

# %%
#Can we have multiple index ?? Let's TRY

# %%
index_val=[('cse',2021),('ece',2022),('cse',2023),('ece',2024),('cse',2025),('cse',2026),('cse',2027),('ece',2028)]

# %%
a=pd.Series([1,2,3,4,5,6,7,8],index=index_val)
a
# Out:
# (cse, 2021)    1
# (ece, 2022)    2
# (cse, 2023)    3
# (ece, 2024)    4
# (cse, 2025)    5
# (cse, 2026)    6
# (cse, 2027)    7
# (ece, 2028)    8
# dtype: int64

# %%
#The Problem ??
a[('cse')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cse'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 2
#       1 #The Problem ??
# ...

# %%
# The solution -› multiindex series(also known as Hierarchical Indexing)
# multiple index levels within a single index

# %%
#how to create multiindex object
# 1. pd.MultiIndex.from_tuples()
# 1. pd.MultiIndex.from_product()

# %%
# 1.pd.MultiIndex. from_tuples()
index_val=[('cse',2021),('ece',2022),('cse',2023),('ece',2024),('cse',2025),('cse',2026),('cse',2027),('ece',2028)]
multiindex=pd.MultiIndex.from_tuples(index_val)
multiindex.levels[0]
# Out:
# Index(['cse', 'ece'], dtype='object')

# %%
#2.pd.MultiIndex.from_product()
a=pd.MultiIndex.from_product([['cse','ece'],[2019,2020,2021,2022]])

# %%
s=pd.Series([1,2,3,4,5,6,7,8],index=a)

# %%
#how to fetch items from a series

# %%
s['cse',2022]
# Out:
# np.int64(4)

# %%
#unstack
temp=s.unstack()

# %%
temp.stack()
# Out:
# cse  2019    1
#      2020    2
#      2021    3
#      2022    4
# ece  2019    5
#      2020    6
#      2021    7
#      2022    8
# dtype: int64

# %%
#multindex Datframe

# %%
branch_df=pd.DataFrame([
[1,2],
[3,41],
[5,6],
[7,81],
[9,101],
[11,12],
[13,14],
[15,16],
],index=a,columns=['average_package','students'])

# %%
branch_df.loc['cse']
# Out:
#       average_package  students
# 2019                1         2
# 2020                3        41
# 2021                5         6
# 2022                7        81

# %%
branch_df.loc['ece']
# Out:
#       average_package  students
# 2019                9       101
# 2020               11        12
# 2021               13        14
# 2022               15        16

# %% [markdown]
# # Stacking and Unstacking

# %%
branch_df.unstack().stack().stack()
# Out:
# /var/folders/x6/3z1b_1m13nn8gl_5jykvtxy40000gn/T/ipykernel_1550/3621795160.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   branch_df.unstack().stack().stack()
# cse  2019  average_package      1
#            students             2
#      2020  average_package      3
#            students            41
#      2021  average_package      5
#            students             6
#      2022  average_package      7
#            students            81
# ece  2019  average_package      9
#            students           101
#      2020  average_package     11
#            students            12
#      2021  average_package     13
#            students            14
#      2022  average_package     15
#            students            16
# dtype: int64

# %% [markdown]
# # Working with multiindexed dataframe

# %%
branches = ["cse", "ece"]
years = [2019, 2020, 2021, 2022]
index = pd.MultiIndex.from_product([branches, years], names=["branch", "year"])


cities = ["delhi", "mumbai"]
metrics = ["avg_package", "students"]
columns = pd.MultiIndex.from_product([cities,metrics], names=["city", "metric"])


data = [
    [1, 2, 0, 0],
    [3, 4, 0, 0],
    [5, 6, 0, 0],
    [7, 8, 0, 0],
    [9, 10, 0, 0],
    [11, 12, 0, 0],
    [13, 14, 0, 0],
    [15, 16, 0, 0],
]

df = pd.DataFrame(data, index=index, columns=columns)
print(df)
# Out:
# city              delhi               mumbai
# metric      avg_package students avg_package students
# branch year
# cse    2019           1        2           0        0
#        2020           3        4           0        0
#        2021           5        6           0        0
#        2022           7        8           0        0
# ece    2019           9       10           0        0
#        2020          11       12           0        0
#        2021          13       14           0        0
#        2022          15       16           0        0

# %%
#head and tail
df.head()
#shape info
df.shape
df.info()
#duplicated
df.duplicated()
#-> isnull
df.isnull()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 8 entries, ('cse', np.int64(2019)) to ('ece', np.int64(2022))
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (delhi, avg_package)   8 non-null      int64
#  1   (delhi, students)      8 non-null      int64
#  2   (mumbai, avg_package)  8 non-null      int64
#  3   (mumbai, students)     8 non-null      int64
# dtypes: int64(4)
# memory usage: 708.0+ bytes
# city              delhi               mumbai
# metric      avg_package students avg_package students
# branch year
# cse    2019       False    False       False    False
#        2020       False    False       False    False
#        2021       False    False       False    False
#        2022       False    False       False    False
# ece    2019       False    False       False    False
#        2020       False    False       False    False
# ...

# %%
df
# Out:
# city              delhi               mumbai
# metric      avg_package students avg_package students
# branch year
# cse    2019           1        2           0        0
#        2020           3        4           0        0
#        2021           5        6           0        0
#        2022           7        8           0        0
# ece    2019           9       10           0        0
#        2020          11       12           0        0
#        2021          13       14           0        0
#        2022          15       16           0        0

# %%
#Extracting Single row
df.loc[('cse',2022)]
# Out:
# city    metric
# delhi   avg_package    7
#         students       8
# mumbai  avg_package    0
#         students       0
# Name: (cse, 2022), dtype: int64

# %%
df.loc[('cse',2019):('ece',2020):2]
# Out:
# city              delhi               mumbai
# metric      avg_package students avg_package students
# branch year
# cse    2019           1        2           0        0
#        2021           5        6           0        0
# ece    2019           9       10           0        0

# %%
df['delhi']['students']
# Out:
# branch  year
# cse     2019     2
#         2020     4
#         2021     6
#         2022     8
# ece     2019    10
#         2020    12
#         2021    14
#         2022    16
# Name: students, dtype: int64

# %%
df['delhi']['students']
# Out:
# branch  year
# cse     2019     2
#         2020     4
#         2021     6
#         2022     8
# ece     2019    10
#         2020    12
#         2021    14
#         2022    16
# Name: students, dtype: int64

# %%
df
# Out:
# city              delhi               mumbai
# metric      avg_package students avg_package students
# branch year
# cse    2019           1        2           0        0
#        2020           3        4           0        0
#        2021           5        6           0        0
#        2022           7        8           0        0
# ece    2019           9       10           0        0
#        2020          11       12           0        0
#        2021          13       14           0        0
#        2022          15       16           0        0

# %%
df.iloc[[0,4],[1,2]]
# Out:
# city           delhi      mumbai
# metric      students avg_package
# branch year
# cse    2019        2           0
# ece    2019       10           0

# %% [markdown]
# # #sort index
# # both -› descending-› diff

# %%
df
# Out:
# city              delhi               mumbai
# metric      avg_package students avg_package students
# branch year
# cse    2019           1        2           0        0
#        2020           3        4           0        0
#        2021           5        6           0        0
#        2022           7        8           0        0
# ece    2019           9       10           0        0
#        2020          11       12           0        0
#        2021          13       14           0        0
#        2022          15       16           0        0

# %%
df.sort_index(ascending=False)
df.sort_index(ascending=[False,True])
# Out:
# city              delhi               mumbai
# metric      avg_package students avg_package students
# branch year
# ece    2019           9       10           0        0
#        2020          11       12           0        0
#        2021          13       14           0        0
#        2022          15       16           0        0
# cse    2019           1        2           0        0
#        2020           3        4           0        0
#        2021           5        6           0        0
#        2022           7        8           0        0

# %%
df.sort_index(level=1,ascending=False)
# Out:
# city              delhi               mumbai
# metric      avg_package students avg_package students
# branch year
# ece    2022          15       16           0        0
# cse    2022           7        8           0        0
# ece    2021          13       14           0        0
# cse    2021           5        6           0        0
# ece    2020          11       12           0        0
# cse    2020           3        4           0        0
# ece    2019           9       10           0        0
# cse    2019           1        2           0        0

# %%
df.transpose()
# Out:
# branch              cse                 ece
# year               2019 2020 2021 2022 2019 2020 2021 2022
# city   metric
# delhi  avg_package    1    3    5    7    9   11   13   15
#        students       2    4    6    8   10   12   14   16
# mumbai avg_package    0    0    0    0    0    0    0    0
#        students       0    0    0    0    0    0    0    0

# %%
df.swaplevel(axis=1)
# Out:
# metric      avg_package students avg_package students
# city              delhi    delhi      mumbai   mumbai
# branch year
# cse    2019           1        2           0        0
#        2020           3        4           0        0
#        2021           5        6           0        0
#        2022           7        8           0        0
# ece    2019           9       10           0        0
#        2020          11       12           0        0
#        2021          13       14           0        0
#        2022          15       16           0        0

# %% [markdown]
# # Long V/s Wide Data
# 1. ***Wide format is where we have a single row for  every data point with multiple columns to hold the values of various attributes.***
# 2. **Long format is where, for each data point we have as many rows as the number of attributes and each row contains the value of a particular attribute for a given data point.**

# %%
#MELT--> Wide data format ko long me convert karta h 
pd.DataFrame({'cse':[20]}).melt()
# Out:
#   variable  value
# 0      cse     20

# %%
pd.DataFrame({
    'cse':[120],
    'ece':[234],
    'me':[22]
}).melt(var_name='branch',value_name='students')
# Out:
#   branch  students
# 0    cse       120
# 1    ece       234
# 2     me        22

# %%
pd.DataFrame({
    'Branch':['Ece','Bce','mec'],
    '2020':[11,2,3],
    '2021':[23,32,33],
    '2025':[45,96,232]
    }).melt(id_vars=['Branch'],var_name='year',value_name='students')
# Out:
#   Branch  year  students
# 0    Ece  2020        11
# 1    Bce  2020         2
# 2    mec  2020         3
# 3    Ece  2021        23
# 4    Bce  2021        32
# 5    mec  2021        33
# 6    Ece  2025        45
# 7    Bce  2025        96
# 8    mec  2025       232

# %%
#pivot--> long -> Wide

# %%
death=pd.read_csv('coviddeath.csv')
confirm=pd.read_csv('covidconfirm.csv')

# %%
death
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 284            NaN    West Bank and Gaza  31.952200   35.233200        0
# 285            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 286            NaN                 Yemen  15.552727   48.516388        0
# 287            NaN                Zambia -13.133897   27.849332        0
# 288            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  12/24/22  12/25/22  \
# ...

# %%
Death=death.melt(id_vars=['Province/State','Country/Region',"Lat","Long"],var_name='Date',value_name='Death')
confirm=confirm.melt(id_vars=['Province/State','Country/Region',"Lat","Long"],var_name='Date',value_name='Cases')

# %%
Death
# Out:
#        Province/State        Country/Region        Lat        Long     Date  \
# 0                 NaN           Afghanistan  33.939110   67.709953  1/22/20
# 1                 NaN               Albania  41.153300   20.168300  1/22/20
# 2                 NaN               Algeria  28.033900    1.659600  1/22/20
# 3                 NaN               Andorra  42.506300    1.521800  1/22/20
# 4                 NaN                Angola -11.202700   17.873900  1/22/20
# ...               ...                   ...        ...         ...      ...
# 311248            NaN    West Bank and Gaza  31.952200   35.233200   1/2/23
# 311249            NaN  Winter Olympics 2022  39.904200  116.407400   1/2/23
# 311250            NaN                 Yemen  15.552727   48.516388   1/2/23
# 311251            NaN                Zambia -13.133897   27.849332   1/2/23
# 311252            NaN              Zimbabwe -19.015438   29.154857   1/2/23
#
#         Death
# 0           0
# 1           0
# ...

# %%
confirm.merge(Death,on=['Province/State','Country/Region',"Lat","Long",'Date'])[['Country/Region','Date','Cases','Death']]
# Out:
#               Country/Region     Date   Cases  Death
# 0                Afghanistan  1/22/20       0      0
# 1                    Albania  1/22/20       0      0
# 2                    Algeria  1/22/20       0      0
# 3                    Andorra  1/22/20       0      0
# 4                     Angola  1/22/20       0      0
# ...                      ...      ...     ...    ...
# 311248    West Bank and Gaza   1/2/23  703228   5708
# 311249  Winter Olympics 2022   1/2/23     535      0
# 311250                 Yemen   1/2/23   11945   2159
# 311251                Zambia   1/2/23  334661   4024
# 311252              Zimbabwe   1/2/23  259981   5637
#
# [311253 rows x 4 columns]
