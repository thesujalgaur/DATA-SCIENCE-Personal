# %% [markdown]
# # Relational Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
#scatter plot
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(tips,x='total_bill',y='tip',hue='sex',style='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(tips,x='total_bill',y='tip',kind='scatter',hue='sex',style='day',size='size')

# %% [markdown]
# # Line plot

# %%
gap=px.data.gapminder()
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
df=gap[gap['country']=='India']
df
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
#axis level function
sns.lineplot(df,x='year',y='lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.relplot(df,x='year',y='lifeExp',kind='line')

# %%
df=gap[gap['country'].isin(['India','Brazil','Germany','China'])]
df
# Out:
#      country continent  year   lifeExp         pop     gdpPercap iso_alpha  \
# 168   Brazil  Americas  1952  50.91700    56602560   2108.944355       BRA
# 169   Brazil  Americas  1957  53.28500    65551171   2487.365989       BRA
# 170   Brazil  Americas  1962  55.66500    76039390   3336.585802       BRA
# 171   Brazil  Americas  1967  57.63200    88049823   3429.864357       BRA
# 172   Brazil  Americas  1972  59.50400   100840058   4985.711467       BRA
# 173   Brazil  Americas  1977  61.48900   114313951   6660.118654       BRA
# 174   Brazil  Americas  1982  63.33600   128962939   7030.835878       BRA
# 175   Brazil  Americas  1987  65.20500   142938076   7807.095818       BRA
# 176   Brazil  Americas  1992  67.05700   155975974   6950.283021       BRA
# 177   Brazil  Americas  1997  69.38800   168546719   7957.980824       BRA
# 178   Brazil  Americas  2002  71.00600   179914212   8131.212843       BRA
# ...

# %%
sns.relplot(df,x='year',y='lifeExp',kind='line',hue='country',style='continent',size='continent')

# %%
sns.lineplot(df,x='year',y='lifeExp',hue='country')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %% [markdown]
# # facetplot

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(tips,x='total_bill',y='tip',hue='sex',col='sex')

# %%
sns.relplot(tips,x='total_bill',y='tip',hue='sex',row='sex')

# %%
sns.relplot(tips,x='total_bill',y='tip',hue='sex',col='sex',row='day',kind='line')

# %%
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
#col wrap
sns.relplot(gap,x='lifeExp',y='gdpPercap',col='year',col_wrap=3)

# %% [markdown]
# # histogram

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(tips,x='total_bill',kind='hist')

# %%
#bins parameter
sns.displot(tips,x='total_bill',kind='hist',bins=5)

# %%
#note --> applying hist on categorical data

# %%
sns.displot(tips,x='day',kind='hist')

# %%
#hue parameter
sns.displot(tips,x='tip',kind='hist',hue='sex')

# %%
#element Parameter
sns.displot(tips,x='tip',kind='hist',hue='sex',element='step')

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.displot(titanic,x='age',kind='hist',element='step',hue='sex')

# %%
#facetating using col and row
sns.displot(titanic,x='age',kind='hist',col='sex',row='adult_male',element='step')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#fill
sns.displot(tips,x='total_bill',kind='kde',hue='sex',fill=True)

# %% [markdown]
# # RUG plot

# %%
sns.kdeplot(tips,x='total_bill')
sns.rugplot(tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.histplot(tips,x='total_bill',y='tip',cbar=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.kdeplot(tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # matrix plot

# %%
#Heatmap

# %%
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
temp_df=gap.pivot(index='country',columns='year',values='lifeExp')

# %%
plt.figure(figsize=(15,8))
sns.heatmap(temp_df)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
AS=gap[gap['continent']=='Europe'].pivot(index='country',columns='year',values='lifeExp')

# %%
plt.figure(figsize=(15,7))
sns.heatmap(AS,annot=True,linewidths=2,linecolor='black',cmap='winter')
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
#cluster map
iris=px.data.iris()
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
sns.clustermap(iris.iloc[:,[0,1,2,3]])

# %% [markdown]
# # Categorical Scatter Plot

# %%
#Strip plot
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(data=tips,x='day',y='total_bill',hue='day',jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(tips,x='day',y='total_bill',kind='strip',hue='sex')

# %%
sns.catplot(tips,x='day',y='total_bill',kind='swarm',hue='sex')

# %%
sns.swarmplot(tips,x='day',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # boxplot

# %%
sns.boxplot(tips,x='day',y='total_bill',hue='day')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(tips,x='day',y='total_bill',hue='sex',kind='box')

# %%
#single boxplot
sns.boxplot(tips,y='total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# # violin plot

# %%
sns.violinplot(tips,x='day',y='total_bill',hue='day',color='pink')
# Out:
# /var/folders/x6/3z1b_1m13nn8gl_5jykvtxy40000gn/T/ipykernel_985/4274354738.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.violinplot(tips,x='day',y='total_bill',hue='day',color='pink')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(tips,x='day',y='total_bill',hue='sex',color='red',kind='violin',split='True')
# Out:
# /var/folders/x6/3z1b_1m13nn8gl_5jykvtxy40000gn/T/ipykernel_985/623652588.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.catplot(tips,x='day',y='total_bill',hue='sex',color='red',kind='violin',split='True')

# %%
# bar plot
sns.barplot(tips,x='sex',y='total_bill')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(tips,x='sex',y='total_bill',errorbar=None)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
import numpy as np
sns.barplot(tips,x='sex',y='total_bill',hue='smoker',estimator=np.min)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# point plot
