# %%
#speed or list 
lis1=[i for i in range(10000000)]
lis2=[i for i in range(10000000,20000000)]

lis3=[]
import time
start=time.time()
for i in range(len(lis1)):
    lis3.append(lis1[i]+lis2[i])
    
print(time.time()-start)

# %%
#numpy array benifit in terms of time
import numpy as np 
a=np.arange(10000000)
b=np.arange(10000000,20000000)

start=time.time()
c=a+b
print(time.time()-start)

# %%
# numpy array benifit in terms of memory

#List
a=[i for i in range (10000000)]
import sys
sys.getsizeof(a)

# %%
#nparray
a=np.arange(10000000,dtype=np.int8) #Numpy gives flexibility to reduce size 
sys.getsizeof(a)

# %%
#Why Numpy is better than python list
# 1 . time kam leta hai 
# 2. memory bhi kam bhi leta h 
# 3. convienient bhi h

# %% [markdown]
# # Advance indexing

# %%
#Normal indexing and slicing
s=np.arange(24).reshape(6,4)
s

# %%
s[2,1]
s[1:3,1:3]

# %%
#Fancy indexing mr basically hum ek list provide karte hai aur jo bhi humko chahiye hota h 
#hum seedhe  seedhe usko usme daal dete h 
#used a lot in pandas
print(s)
s[[0,2,3]] #fancy indexing row wise
s[[0,2,3,5]]

# %%
#column wise 
s
s[:,[1,3]]

# %% [markdown]
# # Boolean indexing
# 1. 🔹 Boolean Indexing kya hota hai?
#
# **Jab hum NumPy array ya Pandas DataFrame ke elements ko True/False condition ke basis par filter karte hain, usse Boolean Indexing bolte hain.
# Matlab hum ek condition lagayenge aur jo condition True hogi wahi values return hongi.**

# %%
import numpy as np 
a=np.random.randint(1,100,24).reshape(6,4) # randint(range h 1, se 100 ki , fir kitne no. chahiye )
a

# %%
#find all number greater than 50
a>50

# %%
#ab hum is consition ko indexing ki tarah use me le skate hai 
a[a>50]

# %%
#find out even numbers 
a[a%2==0]

# %%
#find the numbers greater than 50 and even 
a[(a>50) & (a%2==0)] #jab bhi boolean values ki baat hogi to '&' use karenge 'and' nahi

# %%
#Not divisible by 7 or 50 se bada 
a[~(a%7==0)&(a>50)]

# %% [markdown]
# # Broadcasting
# 🔹 Broadcasting Kya Hai?
#
# Broadcasting ek NumPy feature hai jo alag-alag size ke arrays ke beech operations ko allow karta hai without explicit looping.
# Matlab agar arrays ka shape alag hai, to NumPy automatically expand/adjust karke operation kar deta hai.

# %%
#same shape
a=np.arange(6).reshape(2,3)
b=np.arange(6,12).reshape(2,3)

print(a)
print(b)
print(a+b) #itemwise edition

# %%
#different shape
a=np.arange(6).reshape(2,3)
b=np.arange(3).reshape(1,3)

print(a)
print(b)
print(a+b)

# %% [markdown]
# # 🔹 Broadcasting Rule
#
# NumPy arrays ke shapes ko right se compare karta hai:
#  1.	Agar dimensions same hain → operation ho jayega.
#  2.	Agar ek dimension me difference hai aur ek side me 1 hai → wo dimension stretch ho jayega.
#  3.	Agar mismatch hai (aur kahin 1 nahi hai) → error milega.

# %% [markdown]
# ![9B920F3E-280E-4957-AABB-F067FFF6126E.jpeg](attachment:9B920F3E-280E-4957-AABB-F067FFF6126E.jpeg)

# %%
#More examples 
a=np.arange(12).reshape(4,3)
b=np.arange(3).reshape(1,3)
print(a)
print(b)
print(a+b)

# %%
#changing shape  
a=np.arange(12).reshape(3,4)
b=np.arange(3)
print(a+b)

# %%
a=np.arange(3).reshape(1,3)
b=np.arange(3).reshape(3,1)
print(a)
print(" ")
print(b)
print(a+b)

# %%
a=np.arange(3).reshape(1,3)
b=np.arange(4).reshape(4,1)
print(a)
print(b)
print(a+b)

# %%
a=np.array([1])
b=np.arange(4).reshape(2,2)
print(a+b)

# %%
a=np.arange(12).reshape(3,4) #dono hi jgh one nahi h toh phir nahi hoga yeh q ki badhayenge 
                              #kisko agar one hi nahi hoga toh 
b=np.arange(12).reshape(4,3)
print(a+b)

# %%
a=np.arange(16).reshape(4,4)
b=np.arange(4).reshape(2,2)
print(a+b)

# %%
a=np.arange(10)
np.sum(a)

np.sin(a)
# Out:
# array([ 0.        ,  0.84147098,  0.90929743,  0.14112001, -0.7568025 ,
#        -0.95892427, -0.2794155 ,  0.6569866 ,  0.98935825,  0.41211849])

# %%
# Working with mathematical Formulas

# sigmoid-->very famous function used mostly in logistic regression
def Sigmoid(arra):
    return 1/(1+np.exp(-(arra)))
arra=np.array([1,2,3,4,5,6,7])
Sigmoid(arra)

#Mean Square Error
# Out:
# array([0.73105858, 0.88079708, 0.95257413, 0.98201379, 0.99330715,
#        0.99752738, 0.99908895])

# %%
#mean Square error
actual=np.random.randint(1,50,25)
predicted=np.random.randint(1,50,25)
actual
# Out:
# array([ 3, 11, 29, 43, 40, 13, 40, 39, 47, 37, 25, 15, 32, 48, 35, 48, 34,
#        23, 35, 16, 48, 26, 20, 41, 30])

# %%
predicted
# Out:
# array([ 9,  8, 31, 19, 16, 13, 47,  1, 41, 48,  2, 21, 44, 18, 49, 30, 18,
#        45, 45, 16,  2, 27, 30, 22, 14])

# %%
def mse(actual,predicted):
    return np.mean((actual-predicted)**2)

mse(actual,predicted)
# Out:
# np.float64(346.16)

# %%
#binary cross Entropy

def bce(actual,predicted):
  return  -np.mean(actual*np.log(predicted)+(1-actual)*np.log(1-predicted))

actual=np.array([0,1,0,1,1,0])
predicted=np.array([0.9,0.1,0.3,0.3,0.8,0.6])

bce(actual,predicted)
# Out:
# np.float64(1.2175420362401874)

# %%
#working with missing values np.nan
a=np.array([1,2,3,4,np.nan,6])
a
# Out:
# array([ 1.,  2.,  3.,  4., nan,  6.])

# %%
a[~np.isnan(a)]
#jitni bhi nan values thi woh sab hat gyi
# Out:
# array([1., 2., 3., 4., 6.])

# %% [markdown]
# # Plotting Graph

# %%
import matplotlib.pyplot as plt
x=np.linspace(-10,10,100)
y=x

plt.plot(x,y)

# %%
x=np.linspace(-10,10,100)
y=x**2

plt.plot(x,y)

# %%
x=np.linspace(-10,10,100)
y=np.sin(x)

plt.plot(x,y)

# %%
x=np.linspace(-10,10,100)
y=x*np.log(x)
plt.plot(x,y)
# Out:
# /var/folders/x6/3z1b_1m13nn8gl_5jykvtxy40000gn/T/ipykernel_1911/1310864822.py:2: RuntimeWarning: invalid value encountered in log
#   y=x*np.log(x)

# %%
# sigmoid
x=np.linspace(-10,10,100)
y=1/(1+np.exp(-x))

plt.plot(x,y)

# %%
#plotting a scatter plot
